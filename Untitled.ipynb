# %%
from http import HTTPStatus
from dashscope import Application
response = Application.call(
    # 若没有配置环境变量，可用百炼 API Key 将下行替换为：api_key="sk-xxx"。但不建议在生产环境中直接将 API Key 硬编码到代码中，以减少 API Key 泄露风险。
    api_key="sk-9b7fdff3e2674d34ae8bf409d39205e7",
    app_id='aaa0ee485a814a56939a56a030614893',# 替换为实际的应用 ID
    prompt='个人所得税是什么')

if response.status_code != HTTPStatus.OK:
    print(f'request_id={response.request_id}')
    print(f'code={response.status_code}')
    print(f'message={response.message}')
    print(f'请参考文档：https://help.aliyun.com/zh/model-studio/developer-reference/error-code')
else:
    print(response.output.text)
# Out:
# **个人所得税是国家对个人（自然人）取得的各项应税所得征收的一种税，旨在调节收入分配并筹集财政收入。**
#
# 1.  **法规依据明确**：依据《中华人民共和国个人所得税法》（2018年修正，主席令第九号）第一条规定：“在中国境内有住所，或者无住所而一个纳税年度内在中国境内居住累计满一百八十三天的个人，为居民个人。居民个人从中国境内和境外取得的所得，依照本法规定缴纳个人所得税。在中国境内无住所又不居住，或者无住所而一个纳税年度内在中国境内居住累计不满一百八十三天的个人，为非居民个人。非居民个人从中国境内取得的所得，依照本法规定缴纳个人所得税。”
# 2.  **核心定义阐述**：**个人所得税是以自然人取得的应税所得为征税对象的一种直接税**，其本质是调整税务机关与个人在征纳过程中形成的社会关系。根据上述法律及《中华人民共和国个人所得税法实施条例》，它针对个人通过劳动、投资或经营活动获得的收入进行课征，而非针对企业或组织。
# 3.  **征税范围界定**：**征税范围取决于纳税人身份，分为居民个人和非居民个人两类**。居民个人需就全球所得（境内和境外）纳税；非居民个人仅就来源于中国境内的所得纳税（如工资、劳务报酬、财产转让等）。例外情况包括：仅在中国执行短期任务的外国人（如根据税收协定免征），但需符合法定条件。
# 4.  **应税所得项目分类**：**中国现行税法规定了九类法定应税所得项目**，具体包括：（1）工资、薪金所得；（2）劳务报酬所得；（3）稿酬所得；（4）特许权使用费所得；（5）经营所得；（6）利息、股息、红利所得；（7）财产租赁所得；（8）财产转让所得；（9）偶然所得（如中奖收入）。这些项目覆盖了个人主要收入来源，不同项目适用不同计税规则（如综合所得与分类所得）。
# 5.  **社会经济作用简述**：**个人所得税在财政收入和收入分配中扮演重要角色**，作为中国主体税种之一，它占税收总收入比重较高（2023年约占8%），通过累进税率和专项附加扣除（如子女教育、赡养老人）实现“高收入者多缴、低收入者少缴或免缴”的公平原则，促进社会公平与经济稳定。
